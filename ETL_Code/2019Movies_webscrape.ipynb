# %%
# Scrape comments from several 2019 films that pass the test.
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# %%
url = 'https://bechdeltest.com/comments/8744'
response = requests.get(url)

# %%
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup.findAll('div')
# Out:
# [<div class="comment">
#  <a id="comment-1"></a><div class="name"><b>Ken Burke</b> said:</div>
#  <div class="text"> This movie has 7 lead female roles plus some others (there are also a few men but in minor roles), the women talk to each other about a large variety of subjects that aren't man-related, plus it's written by and directed by women. </div>
#  <div class="date">Message posted on 2019-05-14 23:53:45</div>
#  </div>,
#  <div class="name"><b>Ken Burke</b> said:</div>,
#  <div class="text"> This movie has 7 lead female roles plus some others (there are also a few men but in minor roles), the women talk to each other about a large variety of subjects that aren't man-related, plus it's written by and directed by women. </div>,
#  <div class="date">Message posted on 2019-05-14 23:53:45</div>,
#  <div id="addcomment" style="display: none;">
#  <form action="/add/save_comment/" method="post">
#  <fieldset>
#  <legend>Your comment</legend>
#  <p><label for="yourname">Name</label>
# ...

# %%
results = soup.findAll('div')

# %%
# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return title of listing
        title = result.find('div', class_="text").text
        # Identify and return price of listing
        comment = result.div.text
        # Identify and return link to listing
        # link = result.a['href']

        # Print results only if title, price, and link are available
        if (title and comment):
            print('-------------')
            print(title)
            print(comment)
    except AttributeError as e:
        print(e)
# Out:
# -------------
#  This movie has 7 lead female roles plus some others (there are also a few men but in minor roles), the women talk to each other about a large variety of subjects that aren't man-related, plus it's written by and directed by women.
# Ken Burke said:
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'

# %%
aladdin = "The movie shows Jasmine and her handmaiden Dahlia speaking about how Jasmine would love to be sultan but she isnt allowed to because she is a woman"
bemymaybe = "Sasha talks with multiple people about stuff that isnt relating to a man such as Veronica Judy and Jenny"
anna = "Anna frequently talks to her KGB director Olga They basically talk about Annas spy job and if sometimes they talk about a man its only because Anna has to kill him Also Anna sometimes talk to her girlfriend Maud about their relationship and never about men"
endgame = "Theres also comments between Natasha Carol and Okoye about the state of the universe postsnap Okoye tells Natasha about an earthquake Nebula and Rocket which may invalidate this particular example tell Natasha about a bad lead for a space mission Nebula tells Gamora about how she used to try to kill her before becoming more like sisters"
cptmarvel = "saving the world Carol speaks with Dr Wendy Larson about Goose the cat and their mission saving the world"
crawl = "Haley and Beth talk about their mother a hurricane and Haleys swim practice"
lallorona = "The mother Anna asks her daughter Sam if she wants reheated meatloaf for dinner Her daughter reluctantly says meatloaf is okay"
fightfam = "Saraya Paige of the WWE interacts regularly with the female wrestlers who are her training companions throughout the movie one of whom is Kirsten The others are also named One example of interaction includes a conversation on the bus wherein Saraya believes that they are talking about herself but they are in fact talking about Kirstens daughter Other female characters include Julia Sarayas mother who also talks to Saraya about something other than men unnamed kids who Zak Sarayas brother trains Hannah Zaks Girlfriend and AJ Lee who Saraya wrestles for the title of champion"
gisaengchung = "All female characters are named The wife and the female employees talk frequently but mostly about the children focusing on the male children so there is a doubt on whether the test is passed"
godzilla = "The mother and daughter talk to each other about the monsters and about breakfast at the very start of the film They talk about Godzilla who is technically male but they also talk about Mothra who is a female monster Those are the only examples I can think of though Most of the rest of the women in the movie only have passing lines to each other like military orders"
happydday = "Danielle and Tree talks about the canceled house meeting"
hustle = "one woman is trying to talk another into letting her out of jail for instance"
latenight = "female talk show host speaks with female producer about her show"
legomovie2 = "Queen Watevra WaNabi asks Susan to return her crown then Susan apologizes for taking it Lucy and General Mayhem discuss the queens true motivations and plans during their duel If sung exchanges also count then Not Evil has Queen Watevra Wanabi sing with Unikitty about giving the cat her own glittery planet, and Watevra sharing with Lucy a list of flattering adjectives people use to describe her which Lucy then admits she doesnt trust"
mylilpony = "They talk about magic their holiday plans food their feelings"
nancydrew = "Nancy George and Bess talk about Bess getting cyberbullied and how to stop it Helen and Flora talk to Nancy about Floras haunted house the ghosts they see and the clues they find Bess and George also help decipher the clues"
pokemon = "Lucy the female lead asks a female reporter named Cynthia if she could help her report the news story Cynthia declines and makes her take her coffee order"
shazam = "Rosa and Darla have an exchange about Darla joining in the diner conversation"
silence = "Ally talks to both her mother Kelly and her grandmother Lynn about survival"
soni = "Their conversations and issues are about their profession and day to day issues on the job"
toystory4 = "Bo Peep is an extremely strong lead female character with her own ambitions which she achieves on her own She has several interactions with her best friend Giggle McDimples about things besides men and also interacts with Gabby Gabby and Jessie throughout the film with her final interaction with the latter being a loving exchange between friends Bonnie and her mother also talk multiple times about what Bonnie is doing has done or how she is feeling"
wanderingearth = "Han Duoduo and her teacher have a conversation about her classroom distractions Two main female characters Han Duoduo and Zhou Qian It is said they have one about their mission Zhou Qian asks Duoduo to step back from the edge After the earthquake in Sulawesi Zhou Qian asks Duoduo if shes alright"

# %%
aladdin2 = "to be sultan"
bemymaybe2 = "Veronica Judy Jenny"
anna2 = "spy job kill relationship"
endgame2 = "universe earthquake space mission kill"
cptmarvel2 = "save the world mission save the world"
crawl2 = "mother hurricane swim practice"
lallorona2 = "reheated meatloaf meatloaf"
fightfam2 = "female characters kids"
gisaengchung2 = "kids"
godzilla2 = "Godzilla Godzilla breakfast Godzilla Mothra Mothra military order"
happydday2 = "meeting"
hustle2 = "jail"
latenight2 = "talk show"
legomovie22 = "crown queen true plans glittery planet trust"
mylilpony2 = "magic plans food feelings"
nancydrew2 = "cyberbully haunted house ghosts clues clues"
pokemon2 = "news coffee order"
shazam2 = "conversation"
silence2 = "survival"
soni2 = "career career problems"
toystory42 = "friends kids kids feelings"
wanderingearth2 = "classroom mission earthquake shes alright"

# %%
# form a wordcloud based on the comments
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# select comments
text = (aladdin+bemymaybe+anna+endgame+cptmarvel+crawl+lallorona+fightfam+gisaengchung+godzilla+happydday+hustle+latenight+legomovie2+mylilpony+nancydrew+pokemon+shazam+silence+soni+toystory4+wanderingearth)
clean_text = (aladdin2+bemymaybe2+anna2+endgame2+cptmarvel2+crawl2+lallorona2+fightfam2+gisaengchung2+godzilla2+happydday2+hustle2+latenight2+legomovie22+mylilpony2+nancydrew2+pokemon2+shazam2+silence2+soni2+toystory42+wanderingearth2)

# %%
# Create the wordcloud object
wordcloud = WordCloud(width=1712, height=1712, margin=0, background_color="#e8ecef", colormap="CMRmap").generate(text)

# %%
# Display the generated image
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
# Create the clean wordcloud object
wordcloud = WordCloud(width=1712, height=1712, margin=0, background_color="#e8ecef", colormap="CMRmap").generate(clean_text)

# %%
# Display the generated image
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
# save wordcloud to png file
cloud = wordcloud.to_file('2019topics.png')
cloud
