# %%
# Scrape comments from several 2009 films that pass the test.
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# %%
url = 'https://bechdeltest.com/comments/4062'
response = requests.get(url)

# %%
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup.findAll('div')
# Out:
# [<div class="comment">
#  <a id="comment-1"></a><div class="name"><b>Nellie</b> said:</div>
#  <div class="text"> Abbey has several brief conversations with her secretary Theresa and her daughter Ashley about work, school and the strange things taking place in Nome. </div>
#  <div class="date">Message posted on 2013-04-15 21:52:06</div>
#  </div>,
#  <div class="name"><b>Nellie</b> said:</div>,
#  <div class="text"> Abbey has several brief conversations with her secretary Theresa and her daughter Ashley about work, school and the strange things taking place in Nome. </div>,
#  <div class="date">Message posted on 2013-04-15 21:52:06</div>,
#  <div id="addcomment" style="display: none;">
#  <form action="/add/save_comment/" method="post">
#  <fieldset>
#  <legend>Your comment</legend>
#  <p><label for="yourname">Name</label>
#  <input class="" id="yourname" name="name" type="text"/></p>
#  <p><label for="youremail">Email</label>
# ...

# %%
results = soup.findAll('div')

# %%
# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return title of listing
        title = result.find('div', class_="text").text
        # Identify and return price of listing
        comment = result.div.text
        # Identify and return link to listing
        # link = result.a['href']

        # Print results only if title, price, and link are available
        if (title and comment):
            print('-------------')
            print(title)
            print(comment)
    except AttributeError as e:
        print(e)
# Out:
# -------------
#  Abbey has several brief conversations with her secretary Theresa and her daughter Ashley about work, school and the strange things taking place in Nome.
# Nellie said:
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'

# %%
seventeenagain = "At the beginning a named woman gets a promotion and she talks about it with her female friends The woman is portrayed as silly and immature and undeserving of the promotion Then they run into an elevator and talk about shopping The women who gets promoted shouldnt count because the other women are not named"
greta = "Greta talks with her grandmother Katherine about how she wants to die that she wants cable and what she wants to do Greta and her grandmother have many conversations throughout the movie"
adventureland = "the twilight girl talks to another girl about her antisemitism and the twilightgirl talks to her mom well, she yells at her a fight with her stepmother Em gets into an argument with her stepmother Francy over home decor and just generally being pretentious"
albinofarm = "There are a few group scenes in which Stacey and Melody talk to one another about being lost and their school assignment They also talk to Shelby the waitress when she takes their order"
alice = "The Queen of Hearts and Alice have an extended conversation about the Stone of Wonderland"
aboutsteve = "There are two distinct scenes when Mary talks to her new friend Elizabeth about Marys impressive vocabulary and desire to solve lifes puzzles just as one would solve a crossword Additionally Mary and a hearing impaired girl have a conversation about talking too much while Mary attempts to figure out how to get them both out of a collapsed mine"
amelia = "The main character Amelia Hilary Swank talks with Elinor Smith Mia Wasikowska about her career in aviation"
aneducation = "Jenny talks extensively with her mother her female friends and female teachers all of whom are named about her future education and life choices"
astroboy = "gift chainsaw"
awaywego = "Alone with her sister she discusses childhood memories their parents death and how they have each handled it over the years"
badlt = "Frankie and Genevieve Terrences mother in law yell at each other about drugs and sobriety  Thats it for female characters interacting with each other"
boatthatrocked = "Felicity and Margaret Mariannes friend converse albeit briefly about having a cup of tea then again when Margaret shows up as part of the rescue fleet at the end of the movie Felicity calls out to her when she's swimming and Margaret tells her that she's doing wonderfully"
thebox = "Norma chitchats with her mother at a wedding rehearsal dinner and while running errands she frets about her job and money problems with a coworker and she exchanges a few lines with the babysitter"
breakingupwards = "het and her mother talk about being bloated"
bringiton = "Is this you and your mom Wow She must have been an amazing cheerleader necklace No dont I dont really like people touching her stuff Sorry Its fine Its no problem. Here. Okay Come on. You do not wanna be late for your first day of school Right because being the new kid is so much fun Ah-huh Hi so we just figured out your style So are these old clothes Are they supposed to be vintage No more like homeless couture Look I dont care what you label whores think Where Im from this is tight But you’re here now and you kind of stand out like bad teeth Look if you guys want to take this outside, we can do this Hold up jalapeno Yeah Cat you know Its one thing to be a fashion dont but unless you want them to give you a permanent facial, don’t threaten me Im Skyes friend Christina Yeah were on the squad together Youre a cheerleader Go Sea Lions Look no offense but you sound like youve had a cheerbotomy How come people always say No offense right before they offend you Look it’s been  No offense Lina but youre just like them"
009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009 2009"

# %%
# cleaner text
seventeenagain2 = "promotion promotion shopping promotion"
greta2 = "death cable career"
adventureland2 = "antisemitism home decor being pretentious"
albinofarm2 = "being lost school order"
alice2 = "Stone of Wonderland"
aboutsteve2 = "impressive vocabulary life talking too much collapsed mine"
amelia2 = "career aviation"
aneducation2 = "future education life"
astroboy2 = "gift chainsaw"
awaywego2 = "childhood memories parents death"
badlt2 = "drugs sobriety"
boatthatrocked2 = "cup of tea doing wonderfully"
thebox2 = "career money"
breakingupwards2 = "being bloated"
bringiton2 = "cheerleader necklace school style clothes cheerleader cheerleader offense offense"
cmedance2 = "illness religion illness"
carriers2 = "20 questions survive plague cartoon"
case392 = "adoption"
chloe2 = "childhood"
finaldest2 = "Art music travel"
chanel2 = "romance"
shopaholic2 = "money shopping shopping shopping addiction fashion career shopping debt shopping money money dreams retirement shopping fashion donate fashion donate money career dream but credit cards debt auction green scarf"
cracks2 = "forbidden book perfume culpability"
davidsbday2 = "latters botched cake"
deadline2 = "Alice and Lucy travel to the spooky old house and discuss Alices work and how shell cope on her own"
desertflwr2 = "identity"
dragme2 = "mortgage curse cake career alcoholism curse"
traspatio2 = " murder murder"
evangelion2 = " Angel plan combat plan"
findbliss2 = "movies writing casting"
fishtank2 = "waking up argue fight fight dancing friends fight fight"
fourthkind2 = "work school strange things Nome"

# %%
# form a wordcloud based on the comments
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
# select comments
text = ()
clean_text = text = ()

# %%
# Create the wordcloud object
def wcloud(text):
     mask = np.array(Image.open("popcorn.png"))   #choose mask
     stopwords = set(STOPWORDS)
     stopwords.add("friend","female","2009")
wordcloud = WordCloud(width=1712, height=1712, margin=0, background_color="#e8ecef", colormap="CMRmap").generate(text)

# %%
# Create the clean wordcloud object
def wcloud(clean_text):
     mask = np.array(Image.open("popcorn.png"))   #choose mask
wordcloud = WordCloud(width=1712, height=1712, margin=0, background_color="#e8ecef", colormap="CMRmap").generate(clean_text)

# %%
# Display the generated image
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
# Display the generated image
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
# save wordcloud to png file
cloud = wordcloud.to_file('2009topics.png')
cloud

# %%
import nltk
tokens = nltk.word_tokenize(text)
tokens
# Out:
# ['promotion',
#  'promotion',
#  'shopping',
#  'promotiondeath',
#  'cable',
#  'careerantisemitism',
#  'home',
#  'decor',
#  'being',
#  'pretentiousStone',
#  'of',
#  'Wonderlandimpressive',
#  'vocabulary',
#  'life',
#  'talking',
#  'too',
#  'much',
#  'collapsed',
#  'minecareer',
#  'aviationfuture',
#  'education',
#  'lifegift',
#  'chainsawchildhood',
#  'memories',
#  'parents',
#  'deathdrugs',
#  'sobrietycup',
#  'of',
#  'tea',
#  'doing',
#  'wonderfullycareer',
#  'moneybeing',
#  'bloatedcheerleader',
#  'necklace',
#  'school',
#  'style',
#  'clothes',
#  'cheerleader',
#  'cheerleader',
#  'offense',
#  'offenseillness',
#  'religion',
#  'illness20',
#  'questions',
#  'survive',
#  'plague',
#  'cartoonadoptionchildhoodArt',
#  'music',
#  'travelmoney',
#  'shopping',
#  'shopping',
#  'shopping',
#  'addiction',
#  'fashion',
#  'career',
#  'shopping',
#  'debt',
#  'shopping',
#  'money',
#  'money',
#  'dreams',
#  'retirement',
#  'shopping',
# ...

# %%
import nltk
tokens2 = nltk.word_tokenize(clean_text)
tokens2
# Out:
# ['promotion',
#  'promotion',
#  'shopping',
#  'promotiondeath',
#  'cable',
#  'careerantisemitism',
#  'home',
#  'decor',
#  'being',
#  'pretentiousStone',
#  'of',
#  'Wonderlandimpressive',
#  'vocabulary',
#  'life',
#  'talking',
#  'too',
#  'much',
#  'collapsed',
#  'minecareer',
#  'aviationfuture',
#  'education',
#  'lifegift',
#  'chainsawchildhood',
#  'memories',
#  'parents',
#  'deathdrugs',
#  'sobrietycup',
#  'of',
#  'tea',
#  'doing',
#  'wonderfullycareer',
#  'moneybeing',
#  'bloatedcheerleader',
#  'necklace',
#  'school',
#  'style',
#  'clothes',
#  'cheerleader',
#  'cheerleader',
#  'offense',
#  'offenseillness',
#  'religion',
#  'illness20',
#  'questions',
#  'survive',
#  'plague',
#  'cartoonadoptionchildhoodArt',
#  'music',
#  'travelmoney',
#  'shopping',
#  'shopping',
#  'shopping',
#  'addiction',
#  'fashion',
#  'career',
#  'shopping',
#  'debt',
#  'shopping',
#  'money',
#  'money',
#  'dreams',
#  'retirement',
#  'shopping',
# ...

# %%
# Calculate frequency distribution to determine unique text indicating what the conversation topics
# not about men were revealed to be
fdist = nltk.FreqDist(tokens)

# Output top 200 words

for token, frequency in fdist.most_common(200):
    print(u'{};{}'.format(token, frequency<3))
# Out:
# shopping;False
# fashion;False
# career;False
# money;False
# and;False
# fight;False
# promotion;True
# of;True
# school;True
# cheerleader;True
# debt;True
# donate;True
# curse;True
# murder;True
# promotiondeath;True
# cable;True
# careerantisemitism;True
# home;True
# decor;True
# being;True
# pretentiousStone;True
# Wonderlandimpressive;True
# vocabulary;True
# life;True
# talking;True
# too;True
# much;True
# collapsed;True
# minecareer;True
# aviationfuture;True
# education;True
# lifegift;True
# chainsawchildhood;True
# memories;True
# parents;True
# deathdrugs;True
# sobrietycup;True
# tea;True
# doing;True
# wonderfullycareer;True
# moneybeing;True
# bloatedcheerleader;True
# necklace;True
# style;True
# clothes;True
# offense;True
# offenseillness;True
# religion;True
# illness20;True
# questions;True
# survive;True
# plague;True
# cartoonadoptionchildhoodArt;True
# music;True
# travelmoney;True
# addiction;True
# dreams;True
# retirement;True
# dream;True
# but;True
# ...

# %%
# Calculate frequency distribution to determine unique text indicating what the conversation topics
# not about men were revealed to be
fdist2 = nltk.FreqDist(tokens2)

# Output top 200 words

for token, frequency in fdist2.most_common(200):
    print(u'{};{}'.format(tokens2, frequency<3))
# Out:
# ['promotion', 'promotion', 'shopping', 'promotiondeath', 'cable', 'careerantisemitism', 'home', 'decor', 'being', 'pretentiousStone', 'of', 'Wonderlandimpressive', 'vocabulary', 'life', 'talking', 'too', 'much', 'collapsed', 'minecareer', 'aviationfuture', 'education', 'lifegift', 'chainsawchildhood', 'memories', 'parents', 'deathdrugs', 'sobrietycup', 'of', 'tea', 'doing', 'wonderfullycareer', 'moneybeing', 'bloatedcheerleader', 'necklace', 'school', 'style', 'clothes', 'cheerleader', 'cheerleader', 'offense', 'offenseillness', 'religion', 'illness20', 'questions', 'survive', 'plague', 'cartoonadoptionchildhoodArt', 'music', 'travelmoney', 'shopping', 'shopping', 'shopping', 'addiction', 'fashion', 'career', 'shopping', 'debt', 'shopping', 'money', 'money', 'dreams', 'retirement', 'shopping', 'fashion', 'donate', 'fashion', 'donate', 'money', 'career', 'dream', 'but', 'credit', 'cards', 'debt', 'auction', 'green', 'scarfforbidden', 'book', 'perfume', 'culpabilitylatters', 'botched',
# ...

# %%
# plot the frequency distribution
fdist.plot(12)

# %%
# plot the frequency distribution
fdist2.plot(25)
